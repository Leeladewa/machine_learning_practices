# %% [markdown]
# <a href="https://colab.research.google.com/github/Leeladewa/machine_learning_practices/blob/master/HACKANONS_COLAB_25GB_RAM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # New Section

# %%
# hope you dont hidded any bug in this cell otherwise you will loose your subcribers from your channel

# %%
import tensorflow as tf
import numpy as np
from keras.models import load_model
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
from zipfile import ZipFile

with ZipFile("/content/drive/My Drive/Colab Notebooks/archive (1).zip", 'r') as zips:
  zips.extractall("/content")

# %%
files = os.listdir("/content/105_classes_pins_dataset")
print(files)
# Out:
# ['pins_Richard Harmon', 'pins_Miley Cyrus', 'pins_barack obama', 'pins_Tom Hiddleston', 'pins_Ursula Corbero', 'pins_kiernen shipka', 'pins_Danielle Panabaker', 'pins_Pedro Alonso', 'pins_Zac Efron', 'pins_Johnny Depp', 'pins_Josh Radnor', 'pins_camila mendes', 'pins_Emma Stone', 'pins_Hugh Jackman', 'pins_Tom Cruise', 'pins_elizabeth olsen', 'pins_Krysten Ritter', 'pins_elon musk', 'pins_Sarah Wayne Callies', 'pins_Jason Momoa', 'pins_Katharine Mcphee', 'pins_margot robbie', 'pins_Millie Bobby Brown', 'pins_Chris Evans', 'pins_Alex Lawther', 'pins_Gwyneth Paltrow', 'pins_Elizabeth Lail', 'pins_Selena Gomez', 'pins_Anne Hathaway', 'pins_Emilia Clarke', 'pins_Robert Downey Jr', 'pins_grant gustin', 'pins_Lionel Messi', 'pins_Zoe Saldana', 'pins_Jessica Barden', 'pins_Jake Mcdorman', 'pins_Jeremy Renner', 'pins_alycia dabnem carey', 'pins_gal gadot', 'pins_Morgan Freeman', 'pins_Maisie Williams', 'pins_Morena Baccarin', 'pins_Lindsey Morgan', 'pins_Inbar Lavi', 'pins_Brenton Thwaites',
# ...

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(files)
# Out:
# LabelEncoder()

# %%
path = '/content/105_classes_pins_dataset/'
filenames = []
category =  []
for file1 in files:
  for file2 in os.listdir(path+file1):
    filenames.append(file1+'/'+file2)
    category.append(files.index(file1))

# %%
df = pd.DataFrame({
    'filename': filenames,
    'category': category
})
print(df[10000:10010])
# Out:
#                                                 filename  category
# 10000  pins_Leonardo DiCaprio/Leonardo DiCaprio223_25...        58
# 10001  pins_Leonardo DiCaprio/Leonardo DiCaprio192_25...        58
# 10002  pins_Leonardo DiCaprio/Leonardo DiCaprio208_25...        58
# 10003  pins_Leonardo DiCaprio/Leonardo DiCaprio243_25...        58
# 10004  pins_Leonardo DiCaprio/Leonardo DiCaprio64_265...        58
# 10005  pins_Leonardo DiCaprio/Leonardo DiCaprio84_267...        58
# 10006  pins_Leonardo DiCaprio/Leonardo DiCaprio15_251...        58
# 10007  pins_Leonardo DiCaprio/Leonardo DiCaprio59_265...        58
# 10008  pins_Leonardo DiCaprio/Leonardo DiCaprio43_262...        58
# 10009  pins_Leonardo DiCaprio/Leonardo DiCaprio0_2472...        58

# %%
train_data, test_data = train_test_split(df, test_size=0.15, random_state=20)
print(train_data.shape[:])
print(test_data.shape[:])
print(train_data[0:10])
# Out:
# (14903, 2)
# (2631, 2)
#                                               filename  category
# 6163       pins_Jake Mcdorman/Jake Mcdorman29_1308.jpg        35
# 10020           pins_Rami Malek/Rami Malek157_3771.jpg        59
# 1210        pins_Pedro Alonso/Pedro Alonso188_2141.jpg         7
# 5611        pins_Lionel Messi/Lionel Messi247_3147.jpg        32
# 6098       pins_Jake Mcdorman/Jake Mcdorman70_1343.jpg        35
# 1737          pins_Josh Radnor/Josh Radnor118_2157.jpg        10
# 283           pins_Miley Cyrus/Miley Cyrus245_3697.jpg         1
# 3983          pins_Chris Evans/Chris Evans200_1173.jpg        23
# 2374            pins_Tom Cruise/Tom Cruise164_1077.jpg        14
# 7603   pins_Brenton Thwaites/Brenton Thwaites7_908.jpg        44

# %%
path = '/content/105_classes_pins_dataset/'
filenames = []
category =  []
for file1 in files:
  for file2 in os.listdir(path+file1):
    filenames.append(file1+'/'+file2)
    category.append(file1)

# %%
df2 = pd.DataFrame({
    'filenames':filenames,
    'label':category
})
print(df2)
# Out:
#                                                filenames                  label
# 0          pins_Richard Harmon/Richard Harmon226_586.jpg    pins_Richard Harmon
# 1           pins_Richard Harmon/Richard Harmon93_655.jpg    pins_Richard Harmon
# 2           pins_Richard Harmon/Richard Harmon52_624.jpg    pins_Richard Harmon
# 3          pins_Richard Harmon/Richard Harmon133_533.jpg    pins_Richard Harmon
# 4          pins_Richard Harmon/Richard Harmon217_576.jpg    pins_Richard Harmon
# ...                                                  ...                    ...
# 17529  pins_Rebecca Ferguson/Rebecca Ferguson169_390.jpg  pins_Rebecca Ferguson
# 17530  pins_Rebecca Ferguson/Rebecca Ferguson151_376.jpg  pins_Rebecca Ferguson
# 17531   pins_Rebecca Ferguson/Rebecca Ferguson23_437.jpg  pins_Rebecca Ferguson
# 17532  pins_Rebecca Ferguson/Rebecca Ferguson157_381.jpg  pins_Rebecca Ferguson
# 17533   pins_Rebecca Ferguson/Rebecca Ferguson67_487.jpg  pins_Rebecca Ferguson
#
# ...

# %%
train_data1 , test_data1 = train_test_split(df2, test_size=.15,random_state=60)
print(train_data1.shape[:])
print(test_data1.shape[:])
# Out:
# (14903, 2)
# (2631, 2)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as img

# %%
content_image = img.imread("/content/105_classes_pins_dataset/pins_Christian Bale/Christian Bale0_545.jpg")
print(content_image.shape[:])
plt.imshow(content_image)
# Out:
# (155, 145, 3)

# %%
labels = os.listdir("/content/105_classes_pins_dataset/")
no_of_recordings = []
for label in labels:
  face = [f for f in os.listdir("/content/105_classes_pins_dataset/"+label)]
  no_of_recordings.append(len(face))

plt.figure(figsize=(30,5))
index = np.arange(len(labels))
plt.bar(index,no_of_recordings)
plt.xlabel("faces", fontsize=12)
plt.ylabel("no_of_recordings", fontsize=12)
plt.xticks(index, labels,fontsize=15,rotation=60)
plt.title("No of recordings for each faces")
plt.show()

# %%
print(labels[no_of_recordings.index(max(no_of_recordings))])
# Out:
# pins_Leonardo DiCaprio

# %%
print(labels[no_of_recordings.index(min(no_of_recordings))])
# Out:
# pins_Lionel Messi

# %%
from PIL import Image
from tensorflow.keras.preprocessing.image import img_to_array, array_to_img,load_img, smart_resize, ImageDataGenerator

# %%
model = tf.keras.models.Sequential([
    
    tf.keras.layers.Conv2D(16,(3,3),activation='relu', input_shape = (150,150,3)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.25),
    
    
    
    tf.keras.layers.Conv2D(32,(3,3),activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.20),
    
    
    tf.keras.layers.Conv2D(64,(3,3),activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.25),
    
    
    
    tf.keras.layers.Conv2D(128,(3,3),activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.20),
    
    
    tf.keras.layers.Conv2D(256,(3,3),activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D(3,3),
    tf.keras.layers.Dropout(0.25),
    
    
    
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512,activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(.50),
    tf.keras.layers.Dense(1,activation='softmax')
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              (None, 148, 148, 16)      448
# _________________________________________________________________
# batch_normalization (BatchNo (None, 148, 148, 16)      64
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 74, 74, 16)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 74, 74, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 72, 72, 32)        4640
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 72, 72, 32)        128
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 36, 36, 32)        0
# ...

# %%
from keras.optimizers import RMSprop
model.compile(optimizer=RMSprop(lr=0.001),
              loss = 'categorical_crossentropy',
              metrics = ['accuracy'])

# %%
train_len = train_data1.shape[0]
test_len = test_data1.shape[0]
batch_size = 40

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                              rotation_range = 30,
                              shear_range = .2,
                              zoom_range = .2,
                              horizontal_flip = True,
                              width_shift_range = .15,
                              height_shift_range = .15)
train_generator = train_datagen.flow_from_dataframe(train_data1,'/content/105_classes_pins_dataset/',
                                                   x_col = 'filenames',
                                                   y_col = 'label',
                                                   classes = files, 
                                                   target_size = (150, 150),
                                                   class_mode = 'categorical',
                                                   batch_size = 40)
# Out:
# Found 14903 validated image filenames belonging to 105 classes.

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)
test_generator = test_datagen.flow_from_dataframe(test_data1, '/content/105_classes_pins_dataset/',
                                                 x_col = 'filenames',
                                                 y_col = 'label',
                                                  classes= files,
                                                 target_size = (150, 150),
                                                 class_mode = 'categorical',
                                                 batch_size = 40)
# Out:
# Found 2631 validated image filenames belonging to 105 classes.

# %%
fastrun = False 
epochs = 25
history = model.fit_generator(train_generator,
                             epochs = epochs,
                             validation_data = test_generator,
                             validation_steps = test_len//batch_size,
                             steps_per_epoch = train_len//batch_size)
# Out:
# Epoch 1/25
# 372/372 [==============================] - 102s 273ms/step - loss: 4.0699 - accuracy: 0.9905 - val_loss: 3.6553 - val_accuracy: 0.9905
# Epoch 2/25
# 372/372 [==============================] - 102s 273ms/step - loss: 3.9557 - accuracy: 0.9905 - val_loss: 3.6830 - val_accuracy: 0.9903
# Epoch 3/25
# 372/372 [==============================] - 101s 272ms/step - loss: 3.8479 - accuracy: 0.9905 - val_loss: 3.4621 - val_accuracy: 0.9906
# Epoch 4/25
# 372/372 [==============================] - 101s 271ms/step - loss: 3.7746 - accuracy: 0.9905 - val_loss: 3.2918 - val_accuracy: 0.9906
# Epoch 5/25
# 372/372 [==============================] - 101s 271ms/step - loss: 3.7117 - accuracy: 0.9905 - val_loss: 3.4011 - val_accuracy: 0.9905
# Epoch 6/25
# 372/372 [==============================] - 101s 273ms/step - loss: 3.6623 - accuracy: 0.9905 - val_loss: 3.1206 - val_accuracy: 0.9906
# Epoch 7/25
# ...

# %%
model.save_weights('model.h5')

# %%
fig, (ax1,ax2)=plt.subplots(2,1,figsize=(6,6))
ax1.plot(history.history['loss'], color='b',label = 'Training_loss')
ax1.plot(history.history['val_loss'], color='r',label='validation_loss')
ax1.set_xticks(np.arange(1,epochs,1))
ax1.set_yticks(np.arange(0,1,0.1))


ax2.plot(history.history['accuracy'],color='b', label = 'Training_accuracy')
ax2.plot(history.history['val_accuracy'], color='r',label='Validation_accuracy')
ax2.set_xticks(np.arange(1,epochs,1))
legend = plt.legend(loc='best', shadow=True)
plt.tight_layout()
plt.show()

# %%
model.get_weights()
# Out:
# [array([[[[-5.35027310e-03, -1.46409735e-01, -5.44431284e-02,
#            -1.35830283e-01,  1.20003842e-01, -5.84949628e-02,
#             2.69046873e-01, -4.54497673e-02,  3.02420706e-02,
#            -2.37486158e-02, -1.04989685e-01, -2.17205629e-01,
#            -1.84581608e-01,  1.61840260e-01, -2.00555578e-01,
#             4.06523906e-02],
#           [-3.66644263e-02,  8.43794197e-02,  1.22187473e-01,
#            -2.49544784e-01,  1.21470727e-02,  1.40201747e-01,
#             1.94620684e-01,  1.43912777e-01, -1.87464193e-01,
#            -4.21499908e-02, -2.07957193e-01,  4.34161499e-02,
#            -4.41336520e-02, -1.33982643e-01, -4.30316888e-02,
#             4.74191643e-02],
#           [ 5.48251607e-02,  1.91479057e-01,  3.29812095e-02,
#            -2.42137372e-01,  1.37440726e-01,  1.89031005e-01,
#            -2.89090276e-02, -6.62265196e-02, -1.44679651e-01,
#             1.71782579e-02,  9.99875590e-02, -1.80516124e-01,
# ...

# %%
print(model.layers[1])

# %%
history.history
# Out:
# {'accuracy': [0.9904725551605225,
#   0.990469753742218,
#   0.9904773235321045,
#   0.9904802441596985,
#   0.9904760122299194,
#   0.9904823303222656,
#   0.9904751181602478,
#   0.9905007481575012,
#   0.9905335903167725,
#   0.9905455708503723,
#   0.9905497431755066,
#   0.9905314445495605,
#   0.9905732274055481,
#   0.9905887246131897,
#   0.990622878074646,
#   0.9906129240989685,
#   0.990611732006073,
#   0.9906262755393982,
#   0.9906835556030273,
#   0.9906802177429199,
#   0.9906376004219055,
#   0.9906701445579529,
#   0.990718424320221,
#   0.9907292127609253,
#   0.9907055497169495],
#  'loss': [4.069870471954346,
#   3.955660343170166,
#   3.8478798866271973,
#   3.7746400833129883,
#   3.711653709411621,
#   3.662306308746338,
#   3.6059114933013916,
#   3.5475966930389404,
#   3.4995834827423096,
#   3.4462082386016846,
#   3.419501543045044,
#   3.3993172645568848,
#   3.3612377643585205,
#   3.3403282165527344,
#   3.299515962600708,
#   3.288806438446045,
# ...

# %%
test_image = test_data1[0][0:10]

prediction = model.predict(test_image)
prediction.shape[:]
prediction[0]
